# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Jean Nelson** <br>
# Ops Research Analyst

# %% [markdown]
# *I am interested in data science because I want to increase my value in the job market from that of an analyst*

# %% [markdown]
# ### My code performs basic arithmetic operations

# %%
2*3
# Out:
# 6

# %% [markdown]
# This cell includes several of the functions in the assignment
# 1. Item 1
#     - Item 1 <font color=blue>part 1</font>
#     - Item 1 <font color=red>part 2</font>
#     > Using ~strikethrough~
# 2. Item 2
#     - This is a python
#     ![Python.jfif](attachment:Python.jfif)
#     - This is the link to the image
#     [National Geographic](https://www.nationalgeographic.com/animals/reptiles/facts/burmese-python)
